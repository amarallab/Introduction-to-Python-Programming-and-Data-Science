# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunss.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-weight: bold;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsx.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-style: oblique;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsi.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-weight: bold;
#         font-style: oblique;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunso.otf');
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 22pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %% [markdown]
# # Welcome to the Bootcamp!
#
# We have an exciting 7 days of instruction lined up for you! During this time we plan to cover a number of topics and our expectation is that by the end of the bootcamp you will be able to:
#
# * Write basic Python programs
# * Perform data analysis in Python (plotting, averages, etc.)
# * Basic image analysis
# * Scrape web pages
# * Basic textual analysis
# * Basic structured data analysis
#
# It may not sound like a lot, but it's a lot of ground and an impressive array of skills to be starting with! Going forward after the bootcamp you will not only be equipped to use Python in your own research or projects but, more importantly, also know how to answer your own questions and be an independent programmer.
#
# ## Schedule
#
# This is the tentative schedule that we have planned for the next 7 days. There may be minor shifts as some content may run long or short.
#
# ** Day 1 **
# * Basic data types
# * Collection data types
# * Errors and error handling
# * Flow control
#
# ** Day 2 **
# * Filesystems
# * File I/O
# * Functions
#
# ** Day 3 **
# * Package imports
# * Standard Library packages
# * Data visualization
# * Skill review
#
# ** Day 4 **
# * Mini-Project: College graduate employment
# * Image Analysis
#
# ** Day 5 **
# * HTML Parsing
# * Direct download of web content
# * Simulating browsers to download web content
#
# ** Day 6 **
# * Regular expressions
# * Textual analysis
# * Monte Carlo models to analyze text
#
# ** Day 7 **
# * Structured data analysis with Pandas
# * Date parsing
# * Regression analysis
#
# ## Homeworks
#
# Every day there will be a homework to review the skills taught up to that point. These homeworks will be done in an IPython Notebook, exactly the same as how we deliver the lectures. These homeworks will be automatically graded to assign grades.
#
# The instructions for how to upload the homeworks are on the [bootcamp website](http://amarallab.github.io/Introduction-to-Python-Programming-and-Data-Science/homeworks.html).
#
# We will be assigning fail/pass/high-pass grades to help you self-assess how you are progressing in the class. We will also be distributing certificates to students who achieve a pass or high-pass overall grade on the homeworks.
